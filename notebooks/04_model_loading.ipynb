# %% [markdown]
# ## To Access python codes in src

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %% [markdown]
# ## Import

# %%
from src.model_io import load_object

# %% [markdown]
# ## Load the model

# %%
model = load_object(
    "linear_regression.joblib"
)

preprocessor = load_object(
    "preprocessor.joblib"
)

# %% [markdown]
# ## Load the data

# %%
from src.data_loader import load_train_data
from src.preprocessing import (
    split_features_target,
)

train_df = load_train_data()

X, y = split_features_target(train_df)

# %% [markdown]
# ## Transform

# %%
X_processed = preprocessor.transform(X)

# %% [markdown]
# ## Predict

# %%
predictions = model.predict(
    X_processed
)

predictions[:5]
# Out:
# array([228538.76368537, 119934.30365467, 170452.93731721, 276015.86434663,
#        188846.08762839])

# %%
from src.explainability import get_feature_importance
from models.preprocessor import preprocessor
feature_names = preprocessor.get_feature_names_out()

importance_df = get_feature_importance(
    "Random Forest",
    feature_names,
)

importance_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from src.explainability import get_feature_importance
# ----> 2 from models.preprocessor import preprocessor
#       3 feature_names = preprocessor.get_feature_names_out()
#       4
#       5 importance_df = get_feature_importance(
#
# ModuleNotFoundError: No module named 'models.preprocessor'
