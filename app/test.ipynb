# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
from app.predictor import predict

sample = {
    "Overall Qual": "Excellent",
    "Gr Liv Area": 2200,
    "Garage Cars": 3,
    "Total Bsmt SF": 1150,
    "Year Built": 2015,
}

price1 = predict(sample)
price2 = predict(sample)
price3 = predict(sample)

print(price1)
print(price2)
print(price3)
# Out:
# 241828.4
# 241828.4
# 241828.4
